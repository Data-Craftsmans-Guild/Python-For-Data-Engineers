# %% [markdown]
# # Importing CSV Data

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('Datasets/commafile.csv')
data

# %% [markdown]
# ## Importing Non Comma Separated Data

# %% [markdown]
# ## Tab Delimited Data

# %%
data = pd.read_csv('Datasets/tabfile.csv', sep='\t')
data

# %% [markdown]
# ## Space Delimited Files

# %%
data = pd.read_csv('spacefile.csv', sep='\s',engine='python')
data

# %% [markdown]
# ## Character Delimited Files

# %%
data = pd.read_csv('Datasets/characterfile.csv', sep='\_',engine='python')
data

# %%
data = pd.read_csv('Datasets/characterfile2.csv', sep='\+',engine='python')
data

# %% [markdown]
# ## Variable Space Delimited
# http://archive.ics.uci.edu/ml/datasets/Auto+MPG

# %%
data = pd.read_csv('Datasets/auto-mpg.csv',header=None)
data

# %%
data = pd.read_csv('Datasets/auto-mpg.csv', sep='\t',header=None)
data

# %%
data = pd.read_csv('Datasets/auto-mpg.csv',sep='\s+', header=None, names=['mpg','cylinders','displacement','horsepower',' weight','acceleration','model year','origin','car name'])
data

# %% [markdown]
# ## Multiple Delimiters

# %%
data = pd.read_csv('Datasets/multipleseparators.csv', sep='[:,|_]',engine='python')
data
